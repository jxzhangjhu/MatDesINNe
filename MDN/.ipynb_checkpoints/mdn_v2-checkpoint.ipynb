# %%
import numpy as np
import torch
import torch.optim as optim
import logging
import matplotlib.pyplot as plt
from argparse import ArgumentParser
from models import MixtureDensityNetwork
from torch.autograd import Variable

import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
device          = 'cuda:0' if torch.cuda.is_available() else 'cpu'

rng = 0
batch_size = 500
n_epochs = 1000

## MoS2 - 02-18-2021 dataset
data_x = pd.read_csv('../Simulated_DataSets/MoS2/data_x.csv', header=None).values
data_y = pd.read_csv('../Simulated_DataSets/MoS2/data_y.csv', header=None).values

xtrain, xtest, ytrain, ytest = train_test_split(data_x, data_y, test_size=0.2, random_state=rng)

x_train = torch.tensor(xtrain, dtype=torch.float)
y_train = torch.tensor(ytrain, dtype=torch.float)
x_test = torch.tensor(xtest, dtype=torch.float)
y_test = torch.tensor(ytest, dtype=torch.float)

test_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_test, y_test),
    batch_size=batch_size, shuffle=False, drop_last=True)

train_loader = torch.utils.data.DataLoader(
    torch.utils.data.TensorDataset(x_train, y_train),
    batch_size=batch_size, shuffle=True, drop_last=True)


model = MixtureDensityNetwork(dim_in=1, dim_out=7, n_components=3)
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(n_epochs):
    for j, (x, y) in enumerate(train_loader):
        x, y = Variable(x).to(device), Variable(y).to(device)
        optimizer.zero_grad()
        loss = model.loss(y, x).mean()
        loss.backward()
        optimizer.step()
        
    if epoch %10==0:
        print(f"epoch: {epoch}" + f"Loss: {loss.data:.2f}")
# Out:
# epoch: 0Loss: 8034.98
# epoch: 10Loss: 5372.15
# epoch: 20Loss: 3506.16
# epoch: 30Loss: 2086.66
# epoch: 40Loss: 1211.10
# epoch: 50Loss: 737.88
# epoch: 60Loss: 478.29
# epoch: 70Loss: 329.35
# epoch: 80Loss: 232.23
# epoch: 90Loss: 180.99
# epoch: 100Loss: 138.84
# epoch: 110Loss: 114.29
# epoch: 120Loss: 93.60
# epoch: 130Loss: 79.75
# epoch: 140Loss: 69.10
# epoch: 150Loss: 60.05
# epoch: 160Loss: 53.56
# epoch: 170Loss: 48.26
# epoch: 180Loss: 44.40
# epoch: 190Loss: 41.27
# epoch: 200Loss: 38.62
# epoch: 210Loss: 35.43
# epoch: 220Loss: 33.93
# epoch: 230Loss: 32.31
# epoch: 240Loss: 30.84
# epoch: 250Loss: 29.69
# epoch: 260Loss: 28.41
# epoch: 270Loss: 27.76
# epoch: 280Loss: 26.79
# epoch: 290Loss: 26.25
# epoch: 300Loss: 25.44
# epoch: 310Loss: 24.82
# epoch: 320Loss: 24.42
# epoch: 330Loss: 24.01
# epoch: 340Loss: 23.31
# epoch: 350Loss: 23.23
# epoch: 360Loss: 22.90
# epoch: 370Loss: 22.55
# epoch: 380Loss: 22.40
# epoch: 390Loss: 22.39
# epoch: 400Loss: 22.02
# epoch: 410Loss: 21.96
# epoch: 420Loss: 21.83
# epoch: 430Loss: 21.79
# epoch: 440Loss: 21.63
# epoch: 450Loss: 21.64
# epoch: 460Loss: 21.40
# epoch: 470Loss: 21.37
# epoch: 480Loss: 21.32
# epoch: 490Loss: 21.32
# epoch: 500Loss: 21.17
# epoch: 510Loss: 21.14
# epoch: 520Loss: 21.11
# epoch: 530Loss: 21.05
# epoch: 540Loss: 21.11
# epoch: 550Loss: 21.01
# epoch: 560Loss: 20.91
# epoch: 570Loss: 20.92
# epoch: 580Loss: 20.93
# epoch: 590Loss: 20.86
# epoch: 600Loss: 20.84
# epoch: 610Loss: 20.82
# epoch: 620Loss: 20.85
# epoch: 630Loss: 20.82
# epoch: 640Loss: 20.87
# epoch: 650Loss: 20.88
# epoch: 660Loss: 20.81
# epoch: 670Loss: 20.80
# epoch: 680Loss: 20.77
# epoch: 690Loss: 20.85
# epoch: 700Loss: 20.82
# epoch: 710Loss: 20.71
# epoch: 720Loss: 20.76
# epoch: 730Loss: 20.68
# epoch: 740Loss: 20.77
# epoch: 750Loss: 20.78
# epoch: 760Loss: 20.67
# epoch: 770Loss: 20.69
# epoch: 780Loss: 20.64
# epoch: 790Loss: 20.59
# epoch: 800Loss: 20.58
# epoch: 810Loss: 20.58
# epoch: 820Loss: 20.58
# epoch: 830Loss: 20.52
# epoch: 840Loss: 20.56
# epoch: 850Loss: 20.48
# epoch: 860Loss: 20.58
# epoch: 870Loss: 20.50
# epoch: 880Loss: 20.39
# epoch: 890Loss: 20.40
# epoch: 900Loss: 20.35
# epoch: 910Loss: 20.28
# epoch: 920Loss: 20.28
# epoch: 930Loss: 20.23
# epoch: 940Loss: 20.36
# epoch: 950Loss: 20.18
# epoch: 960Loss: 20.09
# epoch: 970Loss: 20.03
# epoch: 980Loss: 19.89
# epoch: 990Loss: 19.95

# %%
## sampling 
n_samps = 1000
y0 = 1.0

y_fix = np.zeros((n_samps, 1)) + y0
y_fix = torch.tensor(y_fix, dtype=torch.float)
samples = model.sample(y_fix)

# %%
samples
# Out:
# tensor([[ 3.3363e+00,  2.6289e+00,  1.1302e+01,  ...,  1.1365e+02,
#           3.0792e+01, -5.8646e-02],
#         [ 3.3769e+00,  3.4687e+00,  1.1849e+01,  ...,  5.5796e+01,
#          -7.5140e+00,  5.2076e-02],
#         [ 2.9034e+00,  2.7416e+00,  1.1379e+01,  ...,  8.2765e+01,
#          -1.7279e+01, -1.7774e-01],
#         ...,
#         [ 3.5319e+00,  3.4584e+00,  1.1896e+01,  ..., -9.8005e+01,
#          -2.2665e+01, -1.0419e-01],
#         [ 2.9263e+00,  3.0651e+00,  1.1453e+01,  ..., -2.1389e+01,
#           1.5579e+02,  3.3624e-01],
#         [ 3.2829e+00,  2.5622e+00,  1.3800e+01,  ...,  3.0871e+01,
#          -6.4528e+01, -3.7406e-01]])
